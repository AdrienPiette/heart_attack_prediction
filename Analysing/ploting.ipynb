# %% [markdown]
# Describe statistics from data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\pieta\OneDrive\Bureau\Heart_attack_model\heart_attack_prediction\Data\heart_cleaned.csv')

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Age distribution
plt.figure(figsize=(10,6))
sns.histplot(data['Age'], bins=30, kde=True, palette='viridis')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\629775276.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Age'], bins=30, kde=True, palette='viridis')

# %%
# gender distribution

# Plotting
plt.figure(figsize=(10, 6))
plt.pie(data['Sex'].value_counts(), labels=data['Sex'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['#ff9999', '#66b3ff'])
plt.title('Sex distribution')
plt.show()

# %%
# Chest pain type distribution
plt.figure(figsize=(10, 6))
sns.countplot(data['ChestPainType'], palette='viridis')
plt.title('Chest Pain Type distribution')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\4287266728.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['ChestPainType'], palette='viridis')

# %%
# Resting Blood Pressure distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['RestingBP'], bins=30, kde=True, palette='viridis')
plt.title('Resting Blood Pressure distribution')
plt.xlabel('Resting Blood Pressure')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\461518265.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['RestingBP'], bins=30, kde=True, palette='viridis')

# %%
# Cholesterol distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Cholesterol'], bins=30, kde=True, palette='viridis')
plt.title('Cholesterol distribution')
plt.xlabel('Cholesterol')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\883475444.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Cholesterol'], bins=30, kde=True, palette='viridis')

# %%
# Fasting Blood Sugar distribution

plt.figure(figsize=(10, 6))
sns.countplot(y=data['FastingBS'], palette='viridis')
plt.title('Fasting blood sugar distribution')
plt.xlabel('count')
plt.ylabel('Fasting Blood Sugar')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\4117044531.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data['FastingBS'], palette='viridis')

# %%
# Resting ECG distribution
plt.figure(figsize=(10, 6))
sns.countplot(data['RestingECG'], palette='viridis')
plt.title('Resting ECG distribution')
plt.xlabel('Resting ECG')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\1670712211.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['RestingECG'], palette='viridis')

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Max Heart Rate distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['MaxHR'], bins=30, kde=True, palette='viridis')
plt.title('Max Heart Rate distribution')
plt.xlabel('Max Heart Rate')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\2470987263.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['MaxHR'], bins=30, kde=True, palette='viridis')

# %%
# Exercise Induced Angina distribution
plt.figure(figsize=(10, 6))
sns.countplot(data['ExerciseAngina'], palette='viridis')
plt.title('Exercise Induced Angina distribution')
plt.xlabel('Exercise Induced Angina')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\3321520106.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['ExerciseAngina'], palette='viridis')

# %%
# Old peak distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Oldpeak'], bins=30, kde=True, palette='viridis')
plt.title('Old peak distribution')
plt.xlabel('Old peak')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\2286772461.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Oldpeak'], bins=30, kde=True, palette='viridis')

# %%
# ST Slope distribution	
plt.figure(figsize=(10, 6))
sns.countplot(data['ST_Slope'], palette='viridis')
plt.title('ST Slope distribution')
plt.xlabel('ST Slope')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\2078163930.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['ST_Slope'], palette='viridis')

# %%
# heart attack distribution
plt.figure(figsize=(10, 6))
sns.countplot(y=data['HeartDisease'], palette='viridis')
plt.title('Heart Disease distribution')
plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\pieta\AppData\Local\Temp\ipykernel_14876\2725534401.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data['HeartDisease'], palette='viridis')
